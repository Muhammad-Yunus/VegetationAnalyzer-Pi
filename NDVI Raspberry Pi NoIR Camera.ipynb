# %%
#load pi camera library 
from picamera.array import PiRGBArray
import matplotlib.pyplot as plt
from picamera import PiCamera
import time

# define PiCamera() object
camera = PiCamera(resolution=(1280, 960), framerate=5)

# define raw capture object, to hold image array data 
# and wait for warming up
rawCapture = PiRGBArray(camera)
time.sleep(3)
 
#capture image
camera.capture(rawCapture, format="bgr")

# get array image from rawCapture object
img = rawCapture.array

#close camera
camera.close()



# show image using matplotlib
imgplot = plt.imshow(img[:,:,::-1])

plt.savefig("img-" + time.strftime("%Y%m%d-%H%M%S", time.localtime()) + ".png")
plt.show()

# %%
import cv2

cv2.imwrite("image-raw-2.jpg", img)
# Out:
# True

# %%
import numpy as np

# %%
h, w, c = img.shape

# %%
h, w, c = img.shape

NIR = np.zeros((h,w), dtype=float)
G = np.zeros((h,w), dtype=float)
B = np.zeros((h,w), dtype=float)

# %%
NIR = img[:, :, 2]
G = img[:, :, 1]
B = img[:, :, 0]

# %%
NDVI = np.zeros((h,w), dtype=float)

# %%
NIR = NIR/255.0
G = G/255.0
B = B/255.0

# %%
NIR.shape, G.shape, B.shape
# Out:
# ((960, 1280), (960, 1280), (960, 1280))

# %%
NDVI = (NIR - B) / (NIR + B)

# %%
# show image using matplotlib
imgplot = plt.imshow(NDVI, cmap='jet')
plt.show()

# %%
plt.savefig("ndvi-" + time.strftime("%Y%m%d-%H%M%S", time.localtime()) + ".png")

# %%
NDVI = (NIR - G) / (NIR + G)

# %%
# show image using matplotlib
imgplot = plt.imshow(NDVI , cmap='jet')
plt.show()

# %%
plt.savefig("ndvi_g-" + time.strftime("%Y%m%d-%H%M%S", time.localtime()) + ".png")

# %%
# show image using matplotlib
imgplot = plt.imshow(NIR)
plt.show()

# %%
plt.savefig("nir-" + time.strftime("%Y%m%d-%H%M%S", time.localtime()) + ".png")

# %%
# show image using matplotlib
imgplot = plt.imshow(B)
plt.show()

# %%
plt.savefig("b-" + time.strftime("%Y%m%d-%H%M%S", time.localtime()) + ".png")

# %%
# show image using matplotlib
imgplot = plt.imshow(G)
plt.show()

# %%
plt.savefig("g-" + time.strftime("%Y%m%d-%H%M%S", time.localtime()) + ".png")
